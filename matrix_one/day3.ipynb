# %%
# !pip install datadotworld
# !pip install datadotworld[pandas]
# Out:
# ...
#      |████████████████████████████████| 163kB 2.7MB/s
# ...
#      |████████████████████████████████| 71kB 6.4MB/s
# ...
#      |████████████████████████████████| 71kB 8.8MB/s
# ...
#      |████████████████████████████████| 92kB 9.9MB/s
# ...
#      |████████████████████████████████| 71kB 6.0MB/s
# ...
#      |████████████████████████████████| 71kB 7.9MB/s
# ...
#      |████████████████████████████████| 245kB 40.5MB/s
# ...
#      |████████████████████████████████| 174kB 46.2MB/s
# ...
#      |████████████████████████████████| 51kB 6.2MB/s
# ...
#   Created wheel for unicodecsv: filename=unicodecsv-0.14.1-cp36-none-any.whl size=10768 sha256=29802c34214d7723cf21a4ffdec5c1969b1b31bd57ca145d434f5ced87469e5a
#   Stored in directory: /root/.cache/pip/wheels/a6/09/e9/e800279c98a0a8c94543f3de6c8a562f60e51363ed26e71283
# ...
#   Created wheel for linear-tsv: filename=linear_tsv-1.1.0-cp36-none-any.whl size=7383 sha256=23d65907726e19f3e3fbdae7ef65e72eb34686d0faf180e581e339e15706dcdc
# ...

# %%
# !dw configure
# Out:
# API token (obtained at: https://data.world/settings/advanced): eyJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJwcm9kLXVzZXItY2xpZW50OmR5bGV3c2tpIiwiaXNzIjoiYWdlbnQ6ZHlsZXdza2k6OjFmYWE0ODQ0LTMyYTUtNDU3ZS1hMzU4LTUyNjM1ZjBhYTBkOSIsImlhdCI6MTU4MTQ5NDExOSwicm9sZSI6WyJ1c2VyX2FwaV9yZWFkIiwidXNlcl9hcGlfd3JpdGUiXSwiZ2VuZXJhbC1wdXJwb3NlIjp0cnVlLCJzYW1sIjp7fX0.d_8MNPHKle0wJQ7A7XPBe4KzTvf3Bkrv-G-nl9JjP_JeGvsZ8nCLR0hB6_GlsahTZtoiAn8h3woAa-FydAqRNQ

# %%
from google.colab import drive
import pandas as pd
import numpy as np

import datadotworld as dw

# %%
drive.mount("/content/drive")
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %ls
# Out:
# drive/  sample_data/

# %%
cd "drive/My Drive/Colab Notebooks/dw_matrix"
# Out:
# /content/drive/My Drive/Colab Notebooks/dw_matrix

# %%
# %ls
# Out:
# Hello.ipynb  LICENSE  matrix_one/  README.md

# %%
ls matrix_one
# Out:
# day3.ipynb

# %%
# !mkdir data
# Out:
# mkdir: cannot create directory ‘data’: File exists

# %%
# %ls
# Out:
# data/  Hello.ipynb  LICENSE  matrix_one/  README.md

# %%
# !echo 'data' > .gitignore

# %%
# !git add .gitignore

# %%
data = dw.load_dataset('datafiniti/mens-shoe-prices')

# %%
data.dataframes
# Out:
# LazyLoadedDict({'7004_1': LazyLoadedValue(<pandas.DataFrame>)})

# %%
df = data.dataframes['7004_1']
df.shape
# Out:
# /usr/local/lib/python3.6/dist-packages/datadotworld/models/dataset.py:209: UserWarning: Unable to set data frame dtypes automatically using 7004_1 schema. Data types may need to be adjusted manually. Error: Integer column has NA values in column 10
#   'Error: {}'.format(resource_name, e))
# /usr/local/lib/python3.6/dist-packages/datadotworld/util.py:121: DtypeWarning: Columns (39,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   return self._loader_func()
# (19387, 48)

# %%
df.sample(5)
# Out:
#                          id       asins            brand  ...  vin websiteids  weight
# 4497   AVpfYCNOilAPnD_xaqWU         NaN             TOMS  ...  NaN        NaN     NaN
# 11799  AVpfc7jGLJeJML439dRu         NaN  Unique Bargains  ...  NaN        NaN     NaN
# 14765  AVpfh5J-ilAPnD_xdZAP         NaN      Stacy Adams  ...  NaN        NaN     NaN
# 6365   AVpe7HaFLJeJML43yZ9x  B00SM1YSL6            Casio  ...  NaN        NaN     NaN
# 10890  AVpfpDYGilAPnD_xfjVK         NaN      Dr. Martens  ...  NaN        NaN     NaN
#
# [5 rows x 48 columns]

# %%
df.prices_currency.unique()
# Out:
# array(['USD', 'AUD', 'CAD', 'EUR', nan, 'GBP', 'New with box',
#        'UnbeatableSale.com, Inc. - Walmart.com',
#        'PalmBeach Jewelry - Walmart.com', 'new', 'New without tags',
#        'SHOEBACCA LTD. - Walmart.com', 'Shoes.com',
#        'Wholesale Costume and Party Supplies - Walmart.com'], dtype=object)

# %%
df.prices_currency.value_counts()
# Out:
# USD                                                   18524
# AUD                                                     338
# CAD                                                     303
# EUR                                                     107
# GBP                                                      22
# new                                                       3
# New with box                                              3
# UnbeatableSale.com, Inc. - Walmart.com                    3
# PalmBeach Jewelry - Walmart.com                           3
# Wholesale Costume and Party Supplies - Walmart.com        2
# SHOEBACCA LTD. - Walmart.com                              1
# Shoes.com                                                 1
# New without tags                                          1
# Name: prices_currency, dtype: int64

# %%
df.prices_currency.value_counts(normalize=True)
# Out:
# USD                                                   0.959246
# AUD                                                   0.017503
# CAD                                                   0.015691
# EUR                                                   0.005541
# GBP                                                   0.001139
# new                                                   0.000155
# New with box                                          0.000155
# UnbeatableSale.com, Inc. - Walmart.com                0.000155
# PalmBeach Jewelry - Walmart.com                       0.000155
# Wholesale Costume and Party Supplies - Walmart.com    0.000104
# SHOEBACCA LTD. - Walmart.com                          0.000052
# Shoes.com                                             0.000052
# New without tags                                      0.000052
# Name: prices_currency, dtype: float64

# %%
df_usd = df[ df.prices_currency == 'USD'].copy()

# %%
df_usd.shape
# Out:
# (18524, 48)

# %%
df_usd['prices_amountmin'] = df_usd.prices_amountmin.astype(np.float)

# %%
filter_max = np.percentile( df_usd['prices_amountmin'], 99)
filter_max
# Out:
# 895.0

# %%
df_usd_filter = df_usd[ df_usd['prices_amountmin'] < filter_max]

# %%
df_usd_filter.prices_amountmin.hist(bins=100)

# %%
# %ls matrix_one
# Out:
# day3.ipynb

# %%
# !git add matrix_one/day3.ipynb
# !git commit -m "Read Men's Shoe Prices dataset from data.world"
# Out:
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@c08b30be9648.(none)')

# %%
# !git config --global user.email "konrad.dylewski@gmail.com"
# !git config --global user.name "konraddylewski"
